# %% [markdown]
# # Classification and Regression Trees
# ### `! git clone https://github.com/ds4e/trees`

# %% [markdown]
# ## Trees
# - We've looked at three models -- $k$-NN, $k$-means clustering, linear models -- that each offer different approaches to machine learning:
#     - $k$-NN: Regression/classification, highly non-linear predictor
#     - $k$-MC: Unsupervised learning, greedy algorithm for finding similar groups in the data
#     - Linear Regression: Regression and binary classification, uses means/covariances from the data to pick weights for features
# - Now we'll consider is called a *classification/regression tree* or often a *decision tree*, a supervised learning algorithm for regression and classification
# - This is a supervised learning algorithm for regression and classification, but recursively and greedily "splits" the sample to partition the data to minimize differences in outcomes within the groups
# - Later, a group of trees built in a stochastic way becomes a random forest, so it's worth understanding how trees work

# %% [markdown]
# ## Model
# - There are $N$ observations of data $X$ and outcomes $y$ (supervised learning: same setup as $k$-NN and linear models)
# - We want to use $X$ to predict $\hat{y}$ for future cases $\hat{x}$
# - A *classification/regression/decision tree* is
#   1. A set of *decision nodes* that represent decision points
#   2. A set of edges that represent *choices* at each decision node (data-driven choices)
#   3. A set of *terminal nodes* or *outcomes* at the bottom of the tree (predictions or courses of action)
# - The goal is to build a tree from data that predicts outcomes (classification or regression) for future cases
# - Some people get frisky about whether it's called a *decision tree* or a *classification/regression tree*; I suppose they have a point. Unfortunately, CART is a "branded" acronym and "tree" might be too vague...

# %% [markdown]
# - Here's an example of a classification tree from later predicting which animal class a species belongs to. If the box is true, go left; otherwise right:
#
# <img src="./src/species.png" width="550">

# %% [markdown]
# - Here's an example of a regression tree from later predicting heart failure. If the box is true, go left; otherwise right:
#
# <img src="./src/tree.png" width="550">

# %% [markdown]
# ## Example: Divorce Data
# - There are 54 questions, with Likert-scale-type 0--4 response values (0=Strongly Agree, 1=Agree, 2=Neutral, 3=Disagree, 4=Never), and an outcome of divorce/married
# - You *could* make this into a linear model by interacting all of the pairs and triples and tuples of the questions together, but it would be wildly overfit and uninterpretable. It's unclear what $k$-NN would be doing, since the "distances" are arbitrary and using the Euclidean distance would weight all of the questions equally (some are pretty trivial)
# - Instead, you can fit a decision tree to predict marriage outcomes on the basis of the questions, which seems much more natural and reliable
# - In diagnostic settings, this is extremely popular

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./data/divorce/divorce_data.csv',sep=';') # Load divorce data
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q46  Q47  Q48  Q49  Q50  Q51  \
# 0   2   2   4   1   0   0   0   0   0    0  ...    2    1    3    3    3    2
# 1   4   4   4   4   4   0   0   4   4    4  ...    2    2    3    4    4    4
# 2   2   2   2   2   1   3   2   1   1    2  ...    3    2    3    1    1    1
# 3   3   2   3   2   3   3   3   3   3    3  ...    2    2    3    3    3    3
# 4   2   2   1   1   1   1   0   0   0    0  ...    2    1    2    3    2    2
#
#    Q52  Q53  Q54  Divorce
# 0    3    2    1        1
# 1    4    2    2        1
# 2    2    2    2        1
# 3    2    2    2        1
# 4    2    1    0        1
#
# [5 rows x 55 columns]

# %%
from sklearn.tree import DecisionTreeClassifier # Import the tree classifier
from sklearn.tree import plot_tree # Plot the tree

# Process data:
y = df['Divorce'] # Target variable
X = df.drop(['Divorce'], axis=1) # Features/predictors

# Fit decision tree:
cart = DecisionTreeClassifier() # Create a classifier object
cart = cart.fit(X, y) # Fit the classifier

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
# [Text(0.6666666666666666, 0.875, 'Q18 <= 1.5\ngini = 0.5\nsamples = 170\nvalue = [86, 84]'),
#  Text(0.5, 0.625, 'Q26 <= 1.5\ngini = 0.065\nsamples = 89\nvalue = [86, 3]'),
#  Text(0.5833333333333333, 0.75, 'True  '),
#  Text(0.3333333333333333, 0.375, 'Q40 <= 2.5\ngini = 0.023\nsamples = 87\nvalue = [86, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 86\nvalue = [86, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 81\nvalue = [0, 81]'),
#  Text(0.75, 0.75, '  False')]

# %% [markdown]
# ## Selected Questions
# - Decision trees are typically represented with a *dendrogram*, the plot on the previous slide; these are a popular way of visualizing hierarchical or acyclic relationships:
#     - 18. My spouse and I have similar ideas about how marriage should be (High value/"Never" predicts divorce)
#     - 26. I know my spouse's basic concerns. (High value/"Never" predicts divorce)
#     - 40. We are just starting a fight before I know what is going on. (High value/"Never" predicts divorce)
# - Seems about right? Maybe the last question is overfitting?

# %% [markdown]
# ## Did it "work"?
# - Before we go under the hood of the algorithm, we might want to think a bit about what "good performance" means
# - Like with $k$-MC or $k$-NN, this is a greedy kind of algorithm: Left to its own devices, it searches for a perfect split of the data, where the terminal nodes are as pure as possible in terms of classification
# - In practice, this often means that it is a perfect predictor on the training data
# - In situations like this, we are in the familiar situation of having to split into training and testing data in order to be able to make sense of the question, "How well is the algorithm performing?"

# %% [markdown]
# ## The Confusion Matrix
# - The analog of regression residuals for classification is, roughly the **confusion matrix**
# -  We cross tabulate the actual values for
#
# |  | Predicted Negative | Predicted Positive|
# | :---: | :---:| :---: |
# | Actual Negative | True Negative (TN) | False Positive (FP) |
# | Actual Positive | False Negative (FN) | True Positive (TP) |
#
# - The simplest metric of success with a confusion table is **Accuracy**: The proportion of predictions that were correct, or
# $$ \text{Accuracy} = \dfrac{TN+TP}{TN+FP+FN+TP} = \dfrac{TN+TP}{N} $$

# %%
## Splitting the Sample into Train/Test Sets:
from sklearn.model_selection import train_test_split

## Preprocess Data:
y = df['Divorce']
X = df.drop(['Divorce'], axis=1)

## Split the Sample into Training and Testing Sets:
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=104)

## Fit the Model:
from sklearn import tree # Import the tree classifier
cart = tree.DecisionTreeClassifier() # Create a classifier object
cart = cart.fit(X_train, y_train) # Fit the classifier

## Make Predictions on the Test Set:
y_hat = cart.predict(X_test)

## Confusion Matrix:
tab = pd.crosstab(y_test,y_hat) # Compute confusion matrix
acc = (tab.iloc[0,0]+tab.iloc[1,1])/len(y_test) # Compute Accuracy
#acc = np.trace(tab)/len(y_test)  # Faster way to compute accuracy
print('Accuracy: ', acc, '\n')
pd.crosstab(y_test,y_hat)
# Out:
# Accuracy:  0.9117647058823529
# col_0     0   1
# Divorce
# 0        15   1
# 1         2  16

# %% [markdown]
# ## Performance
# - Since the first question is so diagnostically powerful, the accuracy of the tree is around 91.2%
# - If the performance of the tree was unsatisfactory on the test set, there are things we could do:
#     - If we think the tree is overfitting, we could truncate the tree and limit its depth, so that it isn't making splits on very fine distinctions among a handful of observations
#     - If we think the tree is underfitting, we could program it to avoid making splits that make the subsequent populations too pure, so that it has to use more questions and provide a richer and more complex tree
# - This is a funny case in which I think both criticisms probably apply?

# %% [markdown]
# ## Examples
# - Diagnostic tests in medical settings (symptoms/test results $\rightarrow$ diagnosis; doctors love trees)
# - Any situation where most of the data are mostly categorical rather than numeric
# - High-dimensional data where variable selection for linear model is too difficult or where the arbitrariness of the distance metric in $k$-NN is a concern

# %% [markdown]
# # Growing a Classification Tree

# %% [markdown]
# ## Splits
# - How do we build a tree?
# - To understand the mechanics of building a tree, we need to think about "splitting" data into groups, and then evaluating whether the split is "good" or not
# - In the divorce situation, imagine you are trying to use a particular question, say $Q18$, to split the respondents $i = 1, ..., N$ into two groups: Those who divorce, and those who don't
# - As you vary the cutoff response from 1 to 3, you break the $N$ respondents into two groups: Those strictly below the cutoff and those weakly above it
#     - Cutoff at 1: $\{0\}$ and $\{1, 2, 3, 4\}$
#     - Cutoff at 2: $\{0,1\}$ and $\{2,3,4\}$
#     - Cutoff at 3: $\{0,1,2\}$ and $\{3,4\}$
#     - Cutoff at 4: $\{0,1,2,3\}$ and $\{4\}$
# - Let's look at the frequencies of outcomes across the range of the explanatory variable. Take $Q18$, for example:

# %%
pd.crosstab(y,X.iloc[:,17]) # Notice .iloc, not .loc
# Out:
# Q18       0  1   2   3   4
# Divorce
# 0        78  8   0   0   0
# 1         1  2  16  44  21

# %% [markdown]
# - As you vary the cutoff, what is the proportion of couples strictly below and weakly above the cutoff that divorce?
#   - With a cutoff of 1, the divorce proportion for 0's is $1/79= .013$, but for $\{1,2,3,4\}$ it's $83/91 = .912$.
#   - With a cutoff of 2, the divorce proportion for $\{0,1\}$ is $3/89=.034$, but for $\{2,3,4\}$ it's $81/81=1$.
#   - With a cutoff of 3, the divorce proportion for $\{0,1,2\}$ is $19/105=.181$, but for $\{3,4\}$ it's $65/65=1$.
#   - With a cutoff of 4, the divorce proportion for $\{0,1,2,3\}$ is $63/149=.423$, but for $\{4\}$ it's $21/21=1$.
# - Which splits result in two groups are "most alike"? Which are "most different"?

# %% [markdown]
# ## Mixing
# - What we want is to create groups that are "as different as possible" from each other --- ideally, one group would have 0% divorces and the other would have 100% divorces: That's a perfect predictor
# - We often use the word "purity/impurity" to describe whether the resulting groups are relatively extreme ("pure," 0,1) or mixed ("impure," $ \approx 1/2$)
# - What we do not want is groups that have similar proportions to one another: If one group is 50% and the other is 50%, our predictor/split is not distinguishing the two groups at all
# - So our "ideal error" curve would be largest and single-peaked at 1/2, 0 at 0, 0 at 1, and otherwise smooth/continuous. $x(1-x)$ is the easiest way to do this:

# %%
x = np.linspace(0,1,35)
y = x*(1-x)

plt.plot(x,y, label ='Gini Impurity')
plt.xlabel("Proportion")
plt.ylabel("Gini")
plt.legend(loc='upper left')
plt.title('Gini Impurity')
plt.show()

# %% [markdown]
# ## Gini Impurity
# - For each group $g$ created by the split, we compute the proportion of divorces, $p_g$, compute $p_g(1-p_g)$, and sum over the groups $g$:
#
#     - .013*(1-.013) + .912*(1-.912) # Split into {0}, {1,2,3,4}
#     - .034*(1-.034) + 1*(1-1) # Split into {0,1}, {2,3,4}
#     - .181*(1-.181) + 1*(1-1) # Split into {0,1,2}, {3,4}
#     - .423*(1-.423) + 1*(1-1) # Split into {0,1,3,4}, {4}
#
# - The split with the lowest Gini impurity is 2 --- the first split in the decision tree at the beginning of the lecture

# %%
s1 = .013*(1-.013) + .912*(1-.912) # Split into {0}, {1,2,3,4}
s2 = .034*(1-.034) + 1*(1-1) # Split into {0,1}, {2,3,4}
s3 = .181*(1-.181) + 1*(1-1) # Split into {0,1,2}, {3,4}
s4 = .423*(1-.423) + 1*(1-1) # Split into {0,1,3,4}, {4}
print(s1,s2,s3,s4)
# Out:
# 0.09308699999999996 0.032844 0.14823899999999998 0.24407099999999998

# %% [markdown]
# ## Divorce: Subsequent Splits
# - If $Q18$ is greater than 2, all of those couples get divorced --- there's no further learning to do
# - If $Q18$ is strictly less than 2, there are divorces, and we repeat the process, splitting the subpopulation to minimize Gini impurity
# - $Q26$ is the next question that is optimal to split on, but in principle we would look at all the possible variables (including ones previously used)

# %%
y = df['Divorce']
X = df.drop(['Divorce'], axis=1)

pd.crosstab( y[X['Q17']<2], X.loc[X['Q18']<2,'Q26'] )
# Out:
# Q26       0   1  2
# Divorce
# 0        68  17  0
# 1         1   0  1

# %%
y_k = y[X['Q18']<2]

for k in range( X.shape[1]) : 
        X_k = X[X['Q18']<2].iloc[:,k]
        print(pd.crosstab( y_k, X_k ), '\n')
# Out:
# Q1        0  1  2  3  4
# Divorce
# 0        68  8  6  2  2
# 1         1  0  2  0  0
#
# Q2        0   1  2  3
# Divorce
# 0        57  21  5  3
# 1         1   0  2  0
#
# Q3        0   1   2  3  4
# Divorce
# 0        51  20  11  3  1
# 1         0   2   0  0  1
#
# Q4        0  1  2  4
# Divorce
# 0        73  9  1  3
# 1         1  2  0  0
#
# Q5        0  1  2
# Divorce
# 0        79  5  2
# 1         2  1  0
#
# Q6        0   1  2  4
# Divorce
# 0        64  14  7  1
# 1         1   1  1  0
#
# Q7        0  1
# Divorce
# 0        85  1
# 1         3  0
#
# Q8        0  1  2
# Divorce
# 0        77  7  2
# 1         3  0  0
#
# Q9        0  1
# Divorce
# 0        81  5
# 1         3  0
#
# Q10       0   1  2
# Divorce
# 0        60  17  9
# 1         2   1  0
#
# Q11       0   1
# Divorce
# 0        69  17
# 1         2   1
#
# Q12       0   1  2
# Divorce
# 0        56  26  4
# 1         1   1  1
#
# Q13       0   1  2  3
# Divorce
# 0        45  31  9  1
# 1         1   2  0  0
#
# Q14       0   1  2
# Divorce
# 0        63  21  2
# 1         1   2  0
#
# Q15       0   1  2
# Divorce
# 0        68  16  2
# 1         1   1  1
#
# Q16       0   1  2
# Divorce
# 0        73  12  1
# 1         1   2  0
#
# Q17       0   1  2
# Divorce
# 0        72  13  1
# 1         1   1  1
#
# Q18       0  1
# Divorce
# 0        78  8
# 1         1  2
#
# Q19       0   1  2
# Divorce
# 0        75  10  1
# 1         2   0  1
#
# Q20       0  1
# Divorce
# 0        80  6
# 1         0  3
#
# Q21       0   1
# Divorce
# 0        73  13
# 1         2   1
#
# Q22       0  1
# Divorce
# 0        80  6
# 1         3  0
#
# Q23       0  1  2
# Divorce
# 0        81  3  2
# 1         3  0  0
#
# Q24       0   1  2
# Divorce
# 0        68  13  5
# 1         3   0  0
#
# Q25       0   1  2
# Divorce
# 0        58  27  1
# 1         2   0  1
#
# Q26       0   1  2
# Divorce
# 0        69  17  0
# 1         1   0  2
#
# Q27       0   1
# Divorce
# 0        73  13
# 1         2   1
#
# Q28       0  1  2
# Divorce
# 0        79  7  0
# 1         2  0  1
#
# Q29       0  1
# Divorce
# 0        78  8
# 1         2  1
#
# Q30       0   1  2
# Divorce
# 0        70  15  1
# 1         1   2  0
#
# Q31       0   1   2  4
# Divorce
# 0        42  22  19  3
# 1         0   2   0  1
#
# Q32       0   1  2  3  4
# Divorce
# 0        46  25  9  4  2
# 1         0   2  1  0  0
#
# Q33       0   1  2  3  4
# Divorce
# 0        68  14  2  1  1
# 1         0   3  0  0  0
#
# Q34       0   1  2  3  4
# Divorce
# 0        48  31  5  1  1
# 1         0   2  1  0  0
#
# Q35       0  1  3
# Divorce
# 0        79  6  1
# 1         2  1  0
#
# Q36       0  1
# Divorce
# 0        83  3
# 1         1  2
#
# Q37       0   1  2  4
# Divorce
# 0        48  28  7  3
# 1         1   1  1  0
#
# Q38       0   1  2  3
# Divorce
# 0        61  21  3  1
# 1         1   1  1  0
#
# Q39       0   1  2  3  4
# Divorce
# 0        49  27  9  0  1
# 1         1   0  1  1  0
#
# Q40       0   1  2  3
# Divorce
# 0        71  12  3  0
# 1         0   1  1  1
#
# Q41       0   1  2  3
# Divorce
# 0        54  24  7  1
# 1         1   0  2  0
#
# Q42       0   1   2  3  4
# Divorce
# 0        43  13  20  6  4
# 1         0   2   1  0  0
#
# Q43       0   1   2   3   4
# Divorce
# 0        14  16  29  14  13
# 1         0   1   1   1   0
#
# Q44       0   1   2  3  4
# Divorce
# 0        58  14  12  0  2
# 1         1   0   1  1  0
#
# Q45       0   1   2   3   4
# Divorce
# 0        24  22  14  12  14
# 1         1   0   1   1   0
#
# Q46       0   1   2   3   4
# Divorce
# 0        18  15  17  25  11
# 1         0   0   3   0   0
#
# Q47       0   1   2  3  4
# Divorce
# 0        30  28  13  7  8
# 1         0   2   1  0  0
#
# Q48       0  1   2   3  4
# Divorce
# 0        10  8  42  20  6
# 1         0  1   1   1  0
#
# Q49       0   1   2   3  4
# Divorce
# 0        28  26  17  10  5
# 1         0   0   1   2  0
#
# Q50       0   1   2  3  4
# Divorce
# 0        19  27  31  6  3
# 1         0   1   1  1  0
#
# Q51       0   1   2  3  4
# Divorce
# 0        12  24  38  9  3
# 1         0   1   2  0  0
#
# Q52       0   1   2   3  4
# Divorce
# 0        23  23  17  14  9
# 1         0   1   1   1  0
#
# Q53       0   1   2  3  4
# Divorce
# 0        31  25  18  7  5
# 1         0   1   2  0  0
#
# Q54       0   1   2  3  4
# Divorce
# 0        46  24  14  1  1
# 1         2   1   0  0  0

# %% [markdown]
# - We can look through our remaining predictors to determine if there is one that can best further split the sub-population
# - This iterative process creates a multi-step prediction algorithm, called a *classification/regression tree* or *decision tree*

# %% [markdown]
# ## Growing Decision Trees: How to Fit
# - Building the predictive model iterates on the previous steps. This is roughly called the Iterative Dichotomizer (ID3) algorithm:
#   1. For all of the variables, determine the split for each that minimizes impurity
#   2. Pick the variable that achieves the lowest impurity overall --- this creates a single split in the tree. (We might use this variable again to build the tree.)
#   3. Repeat steps 1 and 2 *for each of the sub-populations created by our previous splits* until the impurity is 0 for the remaining sub-populations (they are perfectly separated by outcome)

# %% [markdown]
# # Regression

# %% [markdown]
# ## Regression Trees and Numeric Regressors
# - What if the outcome, $y$, is numeric rather than categorical?
# - Trees can work really well for regression as well: Don't mistake my enthusiasm for classification applications to mean that they're not useful for regression as well
# - We can use the MSE/SSE on either side of the split to choose where to split:
#
#   1. Pick a split point, $s$ for the predictor/regressor $x$
#   2. On either side of the split, compute the mean values of the outcome, $\bar{y}_L(s)$ and $\bar{y}_R(s)$
#   3. Compute the SSE for the split $s$:
# $$
# \text{SSE}(s) = \sum_{x<s} (y(x) - \bar{y}_L(s))^2 + \sum_{x \ge s} (y(x)-\bar{y}_R(s))^2
# $$
#   4. Choose $s$ to minimize `SSE(s)`
#
# - As we move down the tree, the goal is to reduce the `SSE` along each split/path; stopping rules become critical with numeric outcomes
# - Likewise, this allows the split variable $s$ to be numeric or categorical: Minimization over its values is typically easy to do (e.g. Assignment 1)

# %% [markdown]
# ## A Regression Example
# - We can regress prices on apartment features using the AirBnB data
# - The goal is to illustrate regression using trees: They're not just for classification, even if they excel at that task

# %%
from sklearn.tree import DecisionTreeRegressor # Import the tree classifier
from sklearn.tree import plot_tree # Import the tree classifier
from sklearn.model_selection import train_test_split # Train/test splitter

df = pd.read_csv('./data/airbnb_hw.csv') # Load airbnb data
df['Price'] = pd.to_numeric(df['Price'].str.replace(',',''), errors='coerce') # Clean price
df.head()
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
#    Number of Records  Number Of Reviews  Price  Review Scores Rating
# 0                  1                  0    145                   NaN
# 1                  1                  1     37                   NaN
# 2                  1                  1     28                   NaN
# 3                  1                  0    199                   NaN
# 4                  1                 39    549                  96.0

# %%
sns.boxplot(df['Price'])
plt.show()

def winsorize(x):
    # Convert from pd to np, if necessary:
    if type(x) == 'pandas.core.series.Series':
        x = x.to_numpy()
    # Compute IQR and 25, 75 quantiles:
    pct25, pct75 = np.percentile(x,[25,75])
    iqr = pct75 - pct25
    # Compute whiskers:
    lower_whisker = pct25 - iqr*1.5
    upper_whisker = pct75 + iqr*1.5
    # Windorize x:
    x_winsor = np.copy(x)
    x_winsor[ x < lower_whisker ] = lower_whisker
    x_winsor[ x > upper_whisker ] = upper_whisker
    return(x_winsor)

df['Price'] = winsorize(df['Price']) # Winsorize x?
sns.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
# Process data:
y = df['Price'] 
#y =  np.log(df['Price']) # Compare with log version
#print(y.describe())

# Dummy variables:
type_dummy = pd.get_dummies(df['Property Type'])
room_dummy = pd.get_dummies(df['Room Type'])
nbhd_dummy = pd.get_dummies(df['Neighbourhood '])

vars = ['Beds','Number Of Reviews']
X = pd.concat([df.loc[:,vars], type_dummy, nbhd_dummy, room_dummy],axis=1)

# Train-test split:
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=100)

# Fit decision tree:
cart = DecisionTreeRegressor(max_depth = 3) # Create a regression object
cart = cart.fit(X_train, y_train) # Fit the regression

## Make Predictions on the Test Set
y_hat = cart.predict(X_test)

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
# [Text(0.5, 0.875, 'Entire home/apt <= 0.5\nsquared_error = 7189.04\nsamples = 24382\nvalue = 147.767'),
#  Text(0.25, 0.625, 'Manhattan <= 0.5\nsquared_error = 1893.131\nsamples = 10744\nvalue = 89.269'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'Private room <= 0.5\nsquared_error = 1117.84\nsamples = 6176\nvalue = 76.728'),
#  Text(0.0625, 0.125, 'squared_error = 1629.269\nsamples = 326\nvalue = 58.325'),
#  Text(0.1875, 0.125, 'squared_error = 1069.415\nsamples = 5850\nvalue = 77.754'),
#  Text(0.375, 0.375, 'Number Of Reviews <= 0.5\nsquared_error = 2441.195\nsamples = 4568\nvalue = 106.225'),
#  Text(0.3125, 0.125, 'squared_error = 4406.298\nsamples = 1223\nvalue = 117.73'),
#  Text(0.4375, 0.125, 'squared_error = 1656.619\nsamples = 3345\nvalue = 102.018'),
#  Text(0.75, 0.625, 'Beds <= 2.5\nsquared_error = 6541.536\nsamples = 13638\nvalue = 193.851'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'Manhattan <= 0.5\nsquared_error = 5315.359\nsamples = 11186\nvalue = 182.344'),
#  Text(0.5625, 0.125, 'squared_error = 3435.282\nsamples = 4194\nvalue = 149.669'),
#  Text(0.6875, 0.125, 'squared_error = 5418.502\nsamples = 6992\nvalue = 201.944'),
#  Text(0.875, 0.375, 'Manhattan <= 0.5\nsquared_error = 8775.616\nsamples = 2452\nvalue = 246.346'),
#  Text(0.8125, 0.125, 'squared_error = 8081.184\nsamples = 1230\nvalue = 214.86'),
#  Text(0.9375, 0.125, 'squared_error = 7472.386\nsamples = 1222\nvalue = 278.038')]

# %%
## Residuals, Rsq, RMSE
e = y_test - y_hat
sns.kdeplot(e).set(title='Residuals') # Notice the residuals aren't centered around zero
plt.show()

rsq = 1-np.sum(e**2)/np.sum( (y_test - np.mean(y_train))**2)
RMSE = np.sqrt(np.mean(e**2))

print('Rsq: ', rsq)
print('RMSE: ', RMSE)
# Out:
# Rsq:  0.49955411652830095
# RMSE:  60.91780643125221

# %% [markdown]
# - How are numeric splits for regression actually carried out?
# - This code chunk generates the splitting logic for price (numeric) on beds (categorical)

# %%
y = df['Price'] 
x = X.iloc[:,0] # Number of Beds
x_vals = (x.dropna()).unique()

sns.violinplot(x=x, y= y, inner='quart',fill=False ) # Visualize the split
plt.show()

def error(split,x,y):
    """ Computes SSE, continuous outcome and categorical predictor. """
    mean_L = np.mean( y[x<=split] ) # Mean on the left of the split
    mean_R = np.mean( y[x>split] ) # Mean on the right of the split
    if np.isnan(mean_R) == True:
        MSE = (1/len(y))*( np.sum( (y-mean_L)**2 ))
    elif np.isnan(mean_L) == True:
        MSE = (1/len(y))*( np.sum( (y-mean_R)**2 ))
    else:
        MSE = (1/len(y))*( np.sum( (x<=split) * (y-mean_L)**2 + (x>split) * (y-mean_R)**2 ) ) # Compute MSE
    RMSE = np.sqrt(MSE)
    return RMSE

RMSE = [ error(s,x,y) for s in x_vals ] # List comprehension to compute RMSE

sns.scatterplot(x=x_vals,y=RMSE).set(title='Regression Splitting on Beds', xlabel='SplitValue', ylabel = 'RMSE')
# Out:
# [Text(0.5, 1.0, 'Regression Splitting on Beds'),
#  Text(0.5, 0, 'SplitValue'),
#  Text(0, 0.5, 'RMSE')]

# %% [markdown]
# # Early Stopping Rules

# %% [markdown]
# ## Stopping Rules
# - Overfitting with trees is really common, and the structure of trees provides a variety of strategies to avoid overfit models:
#   - Impose a limit on the depth of the tree: The maximum length of a path from the top to the bottom (`max_depth`)
#   - Impose a lower bound on the impurity that can appear at a terminal node: Don't allow the terminal nodes to be "too pure" (`min_impurity_decrease`)
#   - Impose a limit on how few cases can appear at a terminal node: Don't allow the terminal nodes to be "too small" (`min_samples_leaf`)
# - Imposing a constraint on the max depth is the easiest thing to do: It imposes a hard limit on how many levels the tree can have, but often leads to a very "symmetric" and often flawed predictor
# - Constraining the min impurity or min samples per leaf, instead, allow the tree to go deep when the data are very discerning of the outcome, but also shallow when the data isn't very helpful for differentiating outcomes in $y$
# - We're going to "play" with the stopping rules to see what they do to tree shape
# - Early stopping is a form of **regularization**: Imposing constraints on the model to force it not to overfit

# %%
## Fit the Model:
from sklearn import tree # Import the tree classifier
df = pd.read_csv('./data/divorce/divorce_data.csv',sep=';') # Load divorce data

## Preprocess Data:
y = df['Divorce']
X = df.drop(['Divorce'], axis=1)

## Split the Sample into Training and Testing Sets:
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=100)

cart = tree.DecisionTreeClassifier() # No pruning
#cart = tree.DecisionTreeClassifier(min_samples_leaf = 7) # Control min leaf size
#cart = tree.DecisionTreeClassifier(min_impurity_decrease= .1) # Control min impurity

## Make Predictions on the Test Set:
cart = cart.fit(X_train, y_train) # Fit the classifier
y_hat = cart.predict(X_test)

## Confusion Matrix:
tab = pd.crosstab(y_test,y_hat) # Compute confusion matrix
acc = np.trace(tab)/len(y_test) # Faster way to compute accuracy
print('Accuracy: ', acc, '\n')
pd.crosstab(y_test,y_hat)

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
# Accuracy:  1.0
# [Text(0.6666666666666666, 0.875, 'Q18 <= 1.5\ngini = 0.5\nsamples = 136\nvalue = [68, 68]'),
#  Text(0.5, 0.625, 'Q26 <= 1.5\ngini = 0.081\nsamples = 71\nvalue = [68, 3]'),
#  Text(0.5833333333333333, 0.75, 'True  '),
#  Text(0.3333333333333333, 0.375, 'Q40 <= 2.5\ngini = 0.029\nsamples = 69\nvalue = [68, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 68\nvalue = [68, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 65\nvalue = [0, 65]'),
#  Text(0.75, 0.75, '  False')]

# %%
from sklearn.tree import DecisionTreeRegressor # Import the tree classifier
from sklearn.tree import plot_tree # Import the tree classifier
from sklearn.model_selection import train_test_split # Train/test splitter

df = pd.read_csv('./data/airbnb_hw.csv') # Load airbnb data
df['Price'] = pd.to_numeric(df['Price'].str.replace(',',''), errors='coerce') # Clean price
df.head()

# Process data:
y = df['Price'] 
#y =  np.log(df['Price']) # Compare with and without logs

# Dummy variables:
type_dummy = pd.get_dummies(df['Property Type'])
room_dummy = pd.get_dummies(df['Room Type'])
nbhd_dummy = pd.get_dummies(df['Neighbourhood '])

vars = ['Beds','Number Of Reviews']
X = pd.concat([df.loc[:,vars], type_dummy, nbhd_dummy, room_dummy],axis=1)

## Split the Sample into Training and Testing Sets:
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=104)

#cart = tree.DecisionTreeRegressor(max_depth=5)
cart = tree.DecisionTreeRegressor(min_samples_leaf = 500)

cart = cart.fit(X_train, y_train) # Fit the classifier

## Make Predictions on the Test Set:
y_hat = cart.predict(X_test)
print('Rsq  : ', cart.score(X_test, y_test), '\n')

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
# Rsq  :  0.23681264399837554
# [Text(0.5107142857142857, 0.9545454545454546, 'Entire home/apt <= 0.5\nsquared_error = 41144.382\nsamples = 24382\nvalue = 163.368'),
#  Text(0.24285714285714285, 0.8636363636363636, 'Manhattan <= 0.5\nsquared_error = 4488.278\nsamples = 10817\nvalue = 90.814'),
#  Text(0.3767857142857143, 0.9090909090909092, 'True  '),
#  Text(0.14285714285714285, 0.7727272727272727, 'Beds <= 1.5\nsquared_error = 2586.209\nsamples = 6182\nvalue = 77.418'),
#  Text(0.11428571428571428, 0.6818181818181818, 'Brooklyn <= 0.5\nsquared_error = 1335.626\nsamples = 5372\nvalue = 75.581'),
#  Text(0.05714285714285714, 0.5909090909090909, 'Number Of Reviews <= 1.5\nsquared_error = 1085.855\nsamples = 1174\nvalue = 69.316'),
#  Text(0.02857142857142857, 0.5, 'squared_error = 1892.65\nsamples = 525\nvalue = 73.941'),
#  Text(0.08571428571428572, 0.5, 'squared_error = 401.909\nsamples = 649\nvalue = 65.575'),
#  Text(0.17142857142857143, 0.5909090909090909, 'Apartment <= 0.5\nsquared_error = 1391.432\nsamples = 4198\nvalue = 77.333'),
#  Text(0.14285714285714285, 0.5, 'squared_error = 4084.807\nsamples = 707\nvalue = 82.332'),
#  Text(0.2, 0.5, 'Number Of Reviews <= 9.5\nsquared_error = 839.88\nsamples = 3491\nvalue = 76.32'),
#  Text(0.17142857142857143, 0.4090909090909091, 'Number Of Reviews <= 0.5\nsquared_error = 925.685\nsamples = 2636\nvalue = 75.281'),
#  Text(0.14285714285714285, 0.3181818181818182, 'squared_error = 1298.742\nsamples = 1141\nvalue = 77.859'),
#  Text(0.2, 0.3181818181818182, 'Number Of Reviews <= 3.5\nsquared_error = 632.02\nsamples = 1495\nvalue = 73.313'),
#  Text(0.17142857142857143, 0.22727272727272727, 'squared_error = 737.403\nsamples = 957\nvalue = 73.214'),
#  Text(0.22857142857142856, 0.22727272727272727, 'squared_error = 444.514\nsamples = 538\nvalue = 73.489'),
#  Text(0.22857142857142856, 0.4090909090909091, 'squared_error = 561.742\nsamples = 855\nvalue = 79.524'),
#  Text(0.17142857142857143, 0.6818181818181818, 'squared_error = 10709.343\nsamples = 810\nvalue = 89.602'),
#  Text(0.34285714285714286, 0.7727272727272727, 'Number Of Reviews <= 0.5\nsquared_error = 6466.603\nsamples = 4635\nvalue = 108.681'),
#  Text(0.3142857142857143, 0.6818181818181818, 'squared_error = 18654.294\nsamples = 1271\nvalue = 126.966'),
#  Text(0.37142857142857144, 0.6818181818181818, 'Number Of Reviews <= 20.5\nsquared_error = 1687.75\nsamples = 3364\nvalue = 101.773'),
#  Text(0.34285714285714286, 0.5909090909090909, 'Number Of Reviews <= 8.5\nsquared_error = 1902.074\nsamples = 2490\nvalue = 102.536'),
#  Text(0.3142857142857143, 0.5, 'Number Of Reviews <= 1.5\nsquared_error = 1945.678\nsamples = 1849\nvalue = 101.036'),
#  Text(0.2857142857142857, 0.4090909090909091, 'squared_error = 2440.113\nsamples = 571\nvalue = 102.186'),
#  Text(0.34285714285714286, 0.4090909090909091, 'Number Of Reviews <= 3.5\nsquared_error = 1723.915\nsamples = 1278\nvalue = 100.523'),
#  Text(0.3142857142857143, 0.3181818181818182, 'squared_error = 1842.916\nsamples = 619\nvalue = 100.145'),
#  Text(0.37142857142857144, 0.3181818181818182, 'squared_error = 1611.877\nsamples = 659\nvalue = 100.877'),
#  Text(0.37142857142857144, 0.5, 'squared_error = 1751.099\nsamples = 641\nvalue = 106.861'),
#  Text(0.4, 0.5909090909090909, 'squared_error = 1070.762\nsamples = 874\nvalue = 99.598'),
#  Text(0.7785714285714286, 0.8636363636363636, 'Beds <= 2.5\nsquared_error = 62829.603\nsamples = 13565\nvalue = 221.225'),
#  Text(0.6446428571428571, 0.9090909090909092, '  False'),
#  Text(0.6428571428571429, 0.7727272727272727, 'Manhattan <= 0.5\nsquared_error = 35879.829\nsamples = 11064\nvalue = 196.793'),
#  Text(0.5142857142857142, 0.6818181818181818, 'Beds <= 1.5\nsquared_error = 9712.964\nsamples = 4134\nvalue = 153.672'),
#  Text(0.45714285714285713, 0.5909090909090909, 'Number Of Reviews <= 0.5\nsquared_error = 11871.052\nsamples = 2378\nvalue = 144.578'),
#  Text(0.42857142857142855, 0.5, 'squared_error = 42864.688\nsamples = 528\nvalue = 163.356'),
#  Text(0.4857142857142857, 0.5, 'Number Of Reviews <= 4.5\nsquared_error = 2895.937\nsamples = 1850\nvalue = 139.218'),
#  Text(0.45714285714285713, 0.4090909090909091, 'squared_error = 2448.58\nsamples = 783\nvalue = 133.888'),
#  Text(0.5142857142857142, 0.4090909090909091, 'Number Of Reviews <= 12.5\nsquared_error = 3188.066\nsamples = 1067\nvalue = 143.13'),
#  Text(0.4857142857142857, 0.3181818181818182, 'squared_error = 2817.567\nsamples = 528\nvalue = 143.54'),
#  Text(0.5428571428571428, 0.3181818181818182, 'squared_error = 3550.68\nsamples = 539\nvalue = 142.729'),
#  Text(0.5714285714285714, 0.5909090909090909, 'Number Of Reviews <= 6.5\nsquared_error = 6526.753\nsamples = 1756\nvalue = 165.989'),
#  Text(0.5428571428571428, 0.5, 'squared_error = 7995.14\nsamples = 1085\nvalue = 168.981'),
#  Text(0.6, 0.5, 'squared_error = 4114.503\nsamples = 671\nvalue = 161.151'),
#  Text(0.7714285714285715, 0.6818181818181818, 'Number Of Reviews <= 0.5\nsquared_error = 49718.501\nsamples = 6930\nvalue = 222.515'),
#  Text(0.6857142857142857, 0.5909090909090909, 'Beds <= 1.5\nsquared_error = 94726.948\nsamples = 1664\nvalue = 276.504'),
#  Text(0.6571428571428571, 0.5, 'squared_error = 60991.149\nsamples = 1065\nvalue = 247.976'),
#  Text(0.7142857142857143, 0.5, 'squared_error = 150688.271\nsamples = 599\nvalue = 327.225'),
#  Text(0.8571428571428571, 0.5909090909090909, 'Beds <= 1.5\nsquared_error = 34284.25\nsamples = 5266\nvalue = 205.456'),
#  Text(0.7714285714285715, 0.5, 'Number Of Reviews <= 1.5\nsquared_error = 9340.761\nsamples = 3388\nvalue = 187.161'),
#  Text(0.7428571428571429, 0.4090909090909091, 'squared_error = 37677.295\nsamples = 518\nvalue = 201.986'),
#  Text(0.8, 0.4090909090909091, 'Number Of Reviews <= 28.5\nsquared_error = 4179.531\nsamples = 2870\nvalue = 184.485'),
#  Text(0.7714285714285715, 0.3181818181818182, 'Number Of Reviews <= 11.5\nsquared_error = 4208.59\nsamples = 2369\nvalue = 185.802'),
#  Text(0.7428571428571429, 0.22727272727272727, 'Number Of Reviews <= 6.5\nsquared_error = 4199.129\nsamples = 1693\nvalue = 184.573'),
#  Text(0.7142857142857143, 0.13636363636363635, 'Number Of Reviews <= 3.5\nsquared_error = 4467.167\nsamples = 1174\nvalue = 185.624'),
#  Text(0.6857142857142857, 0.045454545454545456, 'squared_error = 4868.559\nsamples = 606\nvalue = 186.38'),
#  Text(0.7428571428571429, 0.045454545454545456, 'squared_error = 4037.66\nsamples = 568\nvalue = 184.817'),
#  Text(0.7714285714285715, 0.13636363636363635, 'squared_error = 3584.674\nsamples = 519\nvalue = 182.197'),
#  Text(0.8, 0.22727272727272727, 'squared_error = 4219.036\nsamples = 676\nvalue = 188.879'),
#  Text(0.8285714285714286, 0.3181818181818182, 'squared_error = 3995.166\nsamples = 501\nvalue = 178.259'),
#  Text(0.9428571428571428, 0.5, 'Number Of Reviews <= 11.5\nsquared_error = 77590.369\nsamples = 1878\nvalue = 238.46'),
#  Text(0.9142857142857143, 0.4090909090909091, 'Number Of Reviews <= 3.5\nsquared_error = 34823.233\nsamples = 1165\nvalue = 236.52'),
#  Text(0.8857142857142857, 0.3181818181818182, 'squared_error = 50707.302\nsamples = 625\nvalue = 238.472'),
#  Text(0.9428571428571428, 0.3181818181818182, 'squared_error = 16429.382\nsamples = 540\nvalue = 234.261'),
#  Text(0.9714285714285714, 0.4090909090909091, 'squared_error = 147453.153\nsamples = 713\nvalue = 241.63'),
#  Text(0.9142857142857143, 0.7727272727272727, 'Number Of Reviews <= 0.5\nsquared_error = 167728.15\nsamples = 2501\nvalue = 329.308'),
#  Text(0.8857142857142857, 0.6818181818181818, 'squared_error = 539696.68\nsamples = 517\nvalue = 479.834'),
#  Text(0.9428571428571428, 0.6818181818181818, 'Manhattan <= 0.5\nsquared_error = 63355.942\nsamples = 1984\nvalue = 290.083'),
#  Text(0.9142857142857143, 0.5909090909090909, 'squared_error = 47466.881\nsamples = 990\nvalue = 228.063'),
#  Text(0.9714285714285714, 0.5909090909090909, 'squared_error = 71534.344\nsamples = 994\nvalue = 351.854')]

# %%
from sklearn.tree import DecisionTreeRegressor # Import the tree classifier
from sklearn.tree import plot_tree # Import the tree classifier
from sklearn.model_selection import train_test_split # Train/test splitter

df = pd.read_csv('./data/heart_failure/heart_failure_clinical_records_dataset.csv')

y = df['DEATH_EVENT']
vars = ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium',]
X = df.loc[:,vars]

## Split the Sample into Training and Testing Sets:
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=104)

## Fit the tree:
#cart = tree.DecisionTreeRegressor(max_depth=3,random_state=100)
cart = tree.DecisionTreeRegressor(min_samples_leaf=20,random_state=500)

## Make Predictions on the Test Set:
cart = cart.fit(X_train, y_train) # Fit the classifier
y_hat = cart.predict(X_test)
print('Rsq  : ', cart.score(X_test, y_test), '\n')

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
# Rsq  :  0.014568312550717777
# [Text(0.4444444444444444, 0.9166666666666666, 'ejection_fraction <= 27.5\nsquared_error = 0.209\nsamples = 239\nvalue = 0.297'),
#  Text(0.2222222222222222, 0.75, 'creatinine_phosphokinase <= 221.5\nsquared_error = 0.222\nsamples = 45\nvalue = 0.667'),
#  Text(0.3333333333333333, 0.8333333333333333, 'True  '),
#  Text(0.1111111111111111, 0.5833333333333334, 'squared_error = 0.248\nsamples = 20\nvalue = 0.55'),
#  Text(0.3333333333333333, 0.5833333333333334, 'squared_error = 0.182\nsamples = 25\nvalue = 0.76'),
#  Text(0.6666666666666666, 0.75, 'serum_creatinine <= 1.45\nsquared_error = 0.167\nsamples = 194\nvalue = 0.211'),
#  Text(0.5555555555555556, 0.8333333333333333, '  False'),
#  Text(0.5555555555555556, 0.5833333333333334, 'age <= 67.5\nsquared_error = 0.116\nsamples = 157\nvalue = 0.134'),
#  Text(0.3333333333333333, 0.4166666666666667, 'platelets <= 313500.0\nsquared_error = 0.057\nsamples = 116\nvalue = 0.06'),
#  Text(0.2222222222222222, 0.25, 'platelets <= 209000.0\nsquared_error = 0.032\nsamples = 90\nvalue = 0.033'),
#  Text(0.1111111111111111, 0.08333333333333333, 'squared_error = 0.122\nsamples = 21\nvalue = 0.143'),
#  Text(0.3333333333333333, 0.08333333333333333, 'squared_error = 0.0\nsamples = 69\nvalue = 0.0'),
#  Text(0.4444444444444444, 0.25, 'squared_error = 0.13\nsamples = 26\nvalue = 0.154'),
#  Text(0.7777777777777778, 0.4166666666666667, 'creatinine_phosphokinase <= 222.0\nsquared_error = 0.225\nsamples = 41\nvalue = 0.341'),
#  Text(0.6666666666666666, 0.25, 'squared_error = 0.245\nsamples = 21\nvalue = 0.429'),
#  Text(0.8888888888888888, 0.25, 'squared_error = 0.188\nsamples = 20\nvalue = 0.25'),
#  Text(0.7777777777777778, 0.5833333333333334, 'squared_error = 0.248\nsamples = 37\nvalue = 0.541')]

# %%
cart = tree.DecisionTreeClassifier(min_samples_leaf = 15) # Create a classifier object
#cart = tree.DecisionTreeClassifier(min_impurity_decrease= .01) # Create a classifier object
#cart = tree.DecisionTreeClassifier(max_depth = 4) # Create a classifier object

cart = cart.fit(X_train, y_train) # Fit the classifier
y_hat = cart.predict(X_test)

## Confusion Matrix:
print('Accuracy  : ', cart.score(X_test, y_test), '\n')
print(pd.crosstab(y_test,y_hat))

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
# Accuracy  :  0.7333333333333333
#
# col_0         0   1
# DEATH_EVENT
# 0            29   6
# 1            10  15
# [Text(0.5833333333333334, 0.9375, 'serum_creatinine <= 1.65\ngini = 0.418\nsamples = 239\nvalue = [168, 71]'),
#  Text(0.3333333333333333, 0.8125, 'ejection_fraction <= 27.5\ngini = 0.333\nsamples = 194\nvalue = [153, 41]'),
#  Text(0.45833333333333337, 0.875, 'True  '),
#  Text(0.25, 0.6875, 'gini = 0.49\nsamples = 28\nvalue = [12, 16]'),
#  Text(0.4166666666666667, 0.6875, 'age <= 74.0\ngini = 0.256\nsamples = 166\nvalue = [141.0, 25.0]'),
#  Text(0.3333333333333333, 0.5625, 'serum_creatinine <= 1.25\ngini = 0.193\nsamples = 148\nvalue = [132, 16]'),
#  Text(0.25, 0.4375, 'platelets <= 318000.0\ngini = 0.144\nsamples = 128\nvalue = [118, 10]'),
#  Text(0.16666666666666666, 0.3125, 'platelets <= 193000.0\ngini = 0.095\nsamples = 100\nvalue = [95, 5]'),
#  Text(0.08333333333333333, 0.1875, 'gini = 0.298\nsamples = 22\nvalue = [18, 4]'),
#  Text(0.25, 0.1875, 'platelets <= 282000.0\ngini = 0.025\nsamples = 78\nvalue = [77, 1]'),
#  Text(0.16666666666666666, 0.0625, 'gini = 0.0\nsamples = 62\nvalue = [62, 0]'),
#  Text(0.3333333333333333, 0.0625, 'gini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.3333333333333333, 0.3125, 'gini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.4166666666666667, 0.4375, 'gini = 0.42\nsamples = 20\nvalue = [14, 6]'),
#  Text(0.5, 0.5625, 'gini = 0.5\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.8333333333333334, 0.8125, 'serum_sodium <= 135.5\ngini = 0.444\nsamples = 45\nvalue = [15, 30]'),
#  Text(0.7083333333333334, 0.875, '  False'),
#  Text(0.75, 0.6875, 'age <= 62.5\ngini = 0.358\nsamples = 30\nvalue = [7, 23]'),
#  Text(0.6666666666666666, 0.5625, 'gini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.8333333333333334, 0.5625, 'gini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.9166666666666666, 0.6875, 'gini = 0.498\nsamples = 15\nvalue = [8, 7]')]

# %% [markdown]
# # Classification, Multiple Outcomes

# %% [markdown]
# ## Multiple Outcomes
# - In our example, Divorce was binary; in many situations, the outcome might have many categorical possibilities (species of animal, type of landmine, non-cancerous/benign/malignant, bond ratings, etc.)
# - Imagine a split creates a "left" group and "right" group, with observations in all the categories on either side of the split
# - For each category $j=1, 2, ..., J$, let $p_{jL}$ be the proportion of outcomes on the left taking the value $j$, and similarly for $p_{jR}$ --- how many mammals on the left? How many malignant tumors on the right?

# %% [markdown]
# - Formally, we split to minimize cross impurity:
# $$
# \underbrace{\sum_{j =1}^J p_{jL}(1-p_{jL})}_{\text{Entropy on the left}} + \underbrace{\sum_{j =1}^J p_{jR}(1-p_{jR})}_{\text{Entropy on the right}}
# $$
# - This can be simplified slightly to
# $$
# 2 - \sum_{j =1}^J p_{jL}^2  - \sum_{j =1}^J p_{jR}^2
# $$
# - You can extend these ideas to more than two splits (i.e. L and R), but most people discourage it

# %% [markdown]
# ### Example: Splitting with multiple labels, categorical predictors
# - For the first example, let's try to classify species by their attributes. There are 7 numeric labels that roughly correspond to things like mammal, fish, bird, crustacean, etc.

# %%
from sklearn.tree import DecisionTreeRegressor # Import the tree classifier
from sklearn.tree import plot_tree # Import the tree classifier
from sklearn.model_selection import train_test_split # Train/test splitter

df = pd.read_csv('./data/zoo.csv')
print(df.head())

y = df['class']
X = df.drop(['class','animal'],axis=1)

## Split the Sample into Training and Testing Sets:
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=.3,
                                                    random_state=104)

#cart = tree.DecisionTreeClassifier(random_state=100)
cart = tree.DecisionTreeClassifier(min_samples_leaf=10,random_state=100)

## Confusion Matrix:
cart = cart.fit(X_train, y_train) # Fit the classifier
y_hat = cart.predict(X_test)
print(pd.crosstab(y_test,y_hat))
print('Accuracy  : ', cart.score(X_test, y_test), '\n')

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
#      animal  hair  feathers  eggs  milk  airborne  aquatic  predator  toothed  \
# 0  aardvark     1         0     0     1         0        0         1        1
# 1  antelope     1         0     0     1         0        0         0        1
# 2      bass     0         0     1     0         0        1         1        1
# 3      bear     1         0     0     1         0        0         1        1
# 4      boar     1         0     0     1         0        0         1        1
#
#    backbone  breathes  venomous  fins  legs  tail  domestic  catsize  class
# 0         1         1         0     0     4     0         0        1      1
# 1         1         1         0     0     4     1         0        1      1
# 2         1         0         0     1     0     1         0        0      4
# 3         1         1         0     0     4     0         0        1      1
# 4         1         1         0     0     4     1         0        1      1
# col_0   1  2  4  6
# class
# 1      12  0  0  0
# 2       0  7  0  0
# 3       0  0  1  0
# 4       0  0  5  0
# 6       0  0  0  2
# 7       0  0  0  4
# Accuracy  :  0.8387096774193549
# [Text(0.6666666666666666, 0.875, 'milk <= 0.5\ngini = 0.76\nsamples = 70\nvalue = [29.0, 13.0, 4.0, 8.0, 4.0, 6.0, 6.0]'),
#  Text(0.5, 0.625, 'feathers <= 0.5\ngini = 0.8\nsamples = 41\nvalue = [0, 13, 4, 8, 4, 6, 6]'),
#  Text(0.5833333333333333, 0.75, 'True  '),
#  Text(0.3333333333333333, 0.375, 'backbone <= 0.5\ngini = 0.786\nsamples = 28\nvalue = [0, 0, 4, 8, 4, 6, 6]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.5\nsamples = 12\nvalue = [0, 0, 0, 0, 0, 6, 6]'),
#  Text(0.5, 0.125, 'gini = 0.625\nsamples = 16\nvalue = [0, 0, 4, 8, 4, 0, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0, 0, 0, 0, 0]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 29\nvalue = [29, 0, 0, 0, 0, 0, 0]'),
#  Text(0.75, 0.75, '  False')]

# %% [markdown]
# - Here's the first split, by whether the species produces milk or not:

# %%
pd.crosstab(X.iloc[:,3],y)
# Out:
# class   1   2  3   4  5  6   7
# milk
# 0       0  20  5  13  4  8  10
# 1      41   0  0   0  0  0   0

# %% [markdown]
# - Mammals detected
# - Here's another multi-class classification example, with landmines:

# %%
from sklearn.tree import DecisionTreeClassifier # Import the tree classifier
from sklearn.tree import plot_tree # Import the tree classifier
from sklearn.model_selection import train_test_split # Train/test splitter

df = pd.read_csv('./data/land_mines.csv')
print(df.head())

y = df['mine_type']
X = df.drop('mine_type',axis=1)

## Split the Sample into Training and Testing Sets:
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.3,random_state=104)

#cart = tree.DecisionTreeClassifier(random_state=100)
#cart = tree.DecisionTreeClassifier(min_impurity_decrease=.1, random_state=100)
cart = tree.DecisionTreeClassifier(min_samples_leaf=10,random_state=100)

cart = cart.fit(X_train, y_train) # Fit the classifier

## Confusion Matrix:
y_hat = cart.predict(X_test)
print('Accuracy  : ', cart.score(X_test, y_test), '\n')
print('Confusion Matrix: \n', pd.crosstab(y_test,y_hat))

# Visualize results:
var_names = cart.feature_names_in_
plot_tree(cart,filled=True,feature_names=var_names)
# Out:
#     voltage    height  soil  mine_type
# 0  0.338157  0.000000   0.0          1
# 1  0.320241  0.181818   0.0          1
# 2  0.287009  0.272727   0.0          1
# 3  0.256284  0.454545   0.0          1
# 4  0.262840  0.545455   0.0          1
# Accuracy  :  0.5
#
# Confusion Matrix:
#  col_0       1   2  3  4   5
# mine_type
# 1          16   0  0  1   7
# 2           0  13  2  1   0
# 3           4   3  2  7   7
# 4           3   3  1  8   6
# 5           2   1  0  3  12
# [Text(0.6764705882352942, 0.9375, 'voltage <= 0.618\ngini = 0.799\nsamples = 236\nvalue = [47, 54, 43, 45, 47]'),
#  Text(0.47058823529411764, 0.8125, 'voltage <= 0.338\ngini = 0.786\nsamples = 199\nvalue = [47, 19, 41, 45, 47]'),
#  Text(0.5735294117647058, 0.875, 'True  '),
#  Text(0.23529411764705882, 0.6875, 'voltage <= 0.289\ngini = 0.669\nsamples = 93\nvalue = [44, 0, 8, 24, 17]'),
#  Text(0.11764705882352941, 0.5625, 'soil <= 0.3\ngini = 0.483\nsamples = 38\nvalue = [24, 0, 1, 13, 0]'),
#  Text(0.058823529411764705, 0.4375, 'gini = 0.117\nsamples = 16\nvalue = [15, 0, 1, 0, 0]'),
#  Text(0.17647058823529413, 0.4375, 'voltage <= 0.256\ngini = 0.483\nsamples = 22\nvalue = [9, 0, 0, 13, 0]'),
#  Text(0.11764705882352941, 0.3125, 'gini = 0.298\nsamples = 11\nvalue = [2, 0, 0, 9, 0]'),
#  Text(0.23529411764705882, 0.3125, 'gini = 0.463\nsamples = 11\nvalue = [7, 0, 0, 4, 0]'),
#  Text(0.35294117647058826, 0.5625, 'height <= 0.5\ngini = 0.716\nsamples = 55\nvalue = [20.0, 0.0, 7.0, 11.0, 17.0]'),
#  Text(0.29411764705882354, 0.4375, 'gini = 0.32\nsamples = 15\nvalue = [12, 0, 0, 0, 3]'),
#  Text(0.4117647058823529, 0.4375, 'voltage <= 0.325\ngini = 0.731\nsamples = 40\nvalue = [8, 0, 7, 11, 14]'),
#  Text(0.35294117647058826, 0.3125, 'height <= 0.773\ngini = 0.671\nsamples = 28\nvalue = [6, 0, 7, 2, 13]'),
#  Text(0.29411764705882354, 0.1875, 'gini = 0.645\nsamples = 11\nvalue = [5, 0, 3, 0, 3]'),
#  Text(0.4117647058823529, 0.1875, 'gini = 0.581\nsamples = 17\nvalue = [1, 0, 4, 2, 10]'),
#  Text(0.47058823529411764, 0.3125, 'gini = 0.403\nsamples = 12\nvalue = [2, 0, 0, 9, 1]'),
#  Text(0.7058823529411765, 0.6875, 'soil <= 0.3\ngini = 0.751\nsamples = 106\nvalue = [3, 19, 33, 21, 30]'),
#  Text(0.5882352941176471, 0.5625, 'voltage <= 0.415\ngini = 0.715\nsamples = 35\nvalue = [0, 10, 8, 13, 4]'),
#  Text(0.5294117647058824, 0.4375, 'gini = 0.626\nsamples = 19\nvalue = [0, 2, 7, 9, 1]'),
#  Text(0.6470588235294118, 0.4375, 'gini = 0.648\nsamples = 16\nvalue = [0, 8, 1, 4, 3]'),
#  Text(0.8235294117647058, 0.5625, 'height <= 0.773\ngini = 0.711\nsamples = 71\nvalue = [3, 9, 25, 8, 26]'),
#  Text(0.7647058823529411, 0.4375, 'voltage <= 0.355\ngini = 0.664\nsamples = 53\nvalue = [3, 1, 20, 7, 22]'),
#  Text(0.7058823529411765, 0.3125, 'gini = 0.64\nsamples = 10\nvalue = [3, 0, 1, 1, 5]'),
#  Text(0.8235294117647058, 0.3125, 'height <= 0.227\ngini = 0.628\nsamples = 43\nvalue = [0, 1, 19, 6, 17]'),
#  Text(0.7647058823529411, 0.1875, 'gini = 0.653\nsamples = 12\nvalue = [0, 0, 3, 4, 5]'),
#  Text(0.8823529411764706, 0.1875, 'voltage <= 0.415\ngini = 0.579\nsamples = 31\nvalue = [0, 1, 16, 2, 12]'),
#  Text(0.8235294117647058, 0.0625, 'gini = 0.604\nsamples = 15\nvalue = [0, 0, 6, 2, 7]'),
#  Text(0.9411764705882353, 0.0625, 'gini = 0.508\nsamples = 16\nvalue = [0, 1, 10, 0, 5]'),
#  Text(0.8823529411764706, 0.4375, 'gini = 0.673\nsamples = 18\nvalue = [0, 8, 5, 1, 4]'),
#  Text(0.8823529411764706, 0.8125, 'voltage <= 0.799\ngini = 0.102\nsamples = 37\nvalue = [0, 35, 2, 0, 0]'),
#  Text(0.7794117647058824, 0.875, '  False'),
#  Text(0.8235294117647058, 0.6875, 'gini = 0.32\nsamples = 10\nvalue = [0, 8, 2, 0, 0]'),
#  Text(0.9411764705882353, 0.6875, 'gini = 0.0\nsamples = 27\nvalue = [0, 27, 0, 0, 0]')]

# %% [markdown]
# ### Example: Splitting with multiple labels, numeric predictor
# - How do we compute the Gini for multiple classes and numeric predictors? Here's an example of a numeric predictor with a multi-class categorical outcome:

# %%
x = X.iloc[:,0]
y = df.loc[:,'mine_type']
x_vals = (x.dropna()).unique()

ax = sns.kdeplot(x=x, hue= y, multiple='fill')
ax = sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

def categorical_error(split,x,y):
    """ Computes Gini impurity for a categorical split. """
    ## Compute Gini on the left of the split:
    y_left = y[x<split] # Labels on the left
    p = (y_left.value_counts()/len(y_left)).to_numpy() # Class probs.
    gini_left = 1 - np.sum( p**2 ) # Compute Gini
    ## Compute Gini on the right of the split:
    y_right = y[x>=split] # Labels on the right
    p = (y_right.value_counts()/len(y_right)).to_numpy() # Class probs.
    gini_right = 1 - np.sum( p**2 ) # Compute Gini
    ## Add Ginis and return:
    gini = gini_left + gini_right
    return gini

impurity = [ categorical_error(s,x,y) for s in x_vals ] # Compute Gini impurity
sns.scatterplot(x=x_vals,y=impurity).set(title='Categorical Splitting on Voltage', 
                                         xlabel='Split Value', ylabel = 'Impurity')

index_optimal = np.where( impurity == np.min(impurity) )
s_optimal = x_vals[index_optimal]
print('Optimal split value: ', s_optimal)
# Out:
# Optimal split value:  [0.75830721]

# %% [markdown]
# - So the optimal split is at .75, where types 4 and 5 drop off to zero

# %% [markdown]
# # Other Details

# %% [markdown]
# ## Entropy: An Alternative to Gini Impurity
# - There are, unsurprisingly, dozens of algorithms and approaches to creating decision-trees!
# - The Gini Impurity is a completely valid way to approach the measurement of how "mixed" or "impure" a split is
# - Many algorithms default to using *entropy* rather than $\sum_{g} p_g(1-p_g)$, defined as
# $$
# \sum_g - p_g \log_2(p_g)
# $$
# with the convention that $0 \log_2(0) = 0$.
# - Mathematically and practically, the Gini Impurity and Entropy Measures are similar
# - Entropy is a complex concept that tries to measure how much "disorder" there is in a system, or how much information you would need to describe its state; its additional mathematical properties motivate its use in decision trees

# %%
def ent(p):
    """ Entropy function. """
    if p == 0:
        e = 0
    else:
        e = - p * np.log2(p)
    return e

p_grid = np.linspace(0,1,100)

Entropy = [ ent(p) for p in p_grid ]
Gini = p_grid*(1-p_grid)

sns.lineplot(x=p_grid,y=Entropy,label='Entropy')
sns.lineplot(x=p_grid,y=Gini,label='Gini')
# Out:
# <Axes: >

# %% [markdown]
# ## Conclusion: Decision Trees
# - There are dozens of variations on this concept (e.g. ID3, C4.5, CART)
# - They express highly non-linear relationships between target variables and data: This can be an advantage in some situations over linear models
# - Many people like how "interpretable" they are: This can be an advantage over $k$-NN
# - They are famously sensitive to the data (a later algorithm, random forests, will address this problem)
# - They are based on discrete splits --- this is simple but works very well on "chunky"/"unitless" data like the divorce Likert scale questions
# - Prediction can be a challenge if the resulting model is "too simple" --- imagine a therapist asking two questions, telling you to get divorced, and asking for payment
